# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb
import sklearn as sk

# %%
mumbai_housing = pd.read_csv('/Users/aatish.jawalkar/Desktop/ML/datasets/mumbai.csv')
mumbai_housing.head()
l = mumbai_housing.loc[mumbai_housing['price']>100000000 ,:]
l
# Out:
#             price                                            Address    area  \
# 16    102000000.0  Rustomjee Seasons Madhusudan Kalelkar Rd near ...  3180.0
# 57    120000000.0  Andheri West, Mumbai., Andheri West, Mumbai - ...  3000.0
# 94    340000000.0  Worli, Mumbai, Worli, Mumbai - South Mumbai, M...  8000.0
# 101   230000000.0  Worli, Mumbai, Worli Sea Face, Mumbai - South ...  4600.0
# 189   107500000.0  Powai, Mumbai, Central Area, Mumbai - Central ...  3000.0
# ...           ...                                                ...     ...
# 6222  110000000.0   Pali Hill, Mumbai - Western Suburbs, Maharashtra  1580.0
# 6224  160000000.0   Malabar Hill, Mumbai - South Mumbai, Maharashtra  1800.0
# 6233  120000000.0        Juhu, Mumbai - Western Suburbs, Maharashtra  3200.0
# 6237  350000000.0  Pali Hill, Bandra West, Mumbai, BR Ambedkar Ch...  8000.0
# 6242  150000000.0  Napean Sea Road, Mumbai - South Mumbai, Mahara...  1600.0
#
# ...

# %%
mumbai_housing.plot.scatter(x='longitude' , y = 'latitude' , c=mumbai_housing['price'], s = mumbai_housing['area']/200 ,alpha = 0.8 ,cmap = 'jet', colorbar = True ,figsize =(10,10) )
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>
